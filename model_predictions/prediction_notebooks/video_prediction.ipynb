# %% [markdown]
# ## Detect Roses and Weeds in a Video
#
# This section uses our trained YOLOv8 model to run inference on a video (`.mov` or `.mp4`).
# It will:
# 1. Run YOLOv8 detection on each frame.
# 2. Save an annotated video with bounding boxes and labels.
# 3. Convert the YOLO output `.avi` to a more friendly format such as `.mp4`
#
# You can use this to visualize how well the model performs on real footage.

# %% [markdown]
# # 1. Imports and paths

# %%
from ultralytics import YOLO
from pathlib import Path
import subprocess

PROJECT_ROOT = Path(r"D:/Ai Systems Group")
MODEL_PATH   = PROJECT_ROOT / "work_dirs/yolov8s-seg-weeds/weights/best.pt"
VIDEO_PATH   = PROJECT_ROOT / "data/weeds_yolo/video/rose_row.mp4"
OUT_DIR      = PROJECT_ROOT / "model_predictions"
VIDEO_PATH = Path(VIDEO_PATH)

MODEL_PATH.exists(), VIDEO_PATH.exists()
# Out:
# (True, True)

# %% [markdown]
# # 2. Run interference

# %%
model = YOLO(str(MODEL_PATH))

results = model.predict(
    source=str(VIDEO_PATH),
    conf=0.30,           # confidence threshold
    imgsz=1024,          # match your training resolution
    device=0,            # GPU (set to 'cpu' if no GPU)
    save=True,           # write the annotated video
    project=str(OUT_DIR),
    name="video_prediction",
    vid_stride=1,        # process every frame (increase to 2+ for speed)
    classes=[0, 1],      # detect roses and weeds (adjust if needed)
)

print(" Saved to:", OUT_DIR / "video_prediction")
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 3 roses, 783.0ms
# video 1/1 (frame 2/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 18 weeds, 4 roses, 872.7ms
# video 1/1 (frame 3/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 4 roses, 857.4ms
# video 1/1 (frame 4/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 18 weeds, 2 roses, 801.7ms
# video 1/1 (frame 5/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 19 weeds, 5 roses, 910.9ms
# video 1/1 (frame 6/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 2 roses, 799.3ms
# video 1/1 (frame 7/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 4 roses, 1255.6ms
# video 1/1 (frame 8/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 2 roses, 918.1ms
# video 1/1 (frame 9/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 20 weeds, 2 roses, 922.5ms
# video 1/1 (frame 10/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 1 rose, 1390.8ms
# video 1/1 (frame 11/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 19 weeds, 1 rose, 820.2ms
# video 1/1 (frame 12/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 20 weeds, 1031.4ms
# video 1/1 (frame 13/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 2 roses, 690.1ms
# video 1/1 (frame 14/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 20 weeds, 1 rose, 846.8ms
# video 1/1 (frame 15/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 606.1ms
# video 1/1 (frame 16/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 646.2ms
# video 1/1 (frame 17/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 15 weeds, 594.1ms
# video 1/1 (frame 18/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 13 weeds, 649.2ms
# video 1/1 (frame 19/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 20 weeds, 612.9ms
# video 1/1 (frame 20/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 15 weeds, 694.1ms
# video 1/1 (frame 21/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 14 weeds, 1511.3ms
# video 1/1 (frame 22/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 854.4ms
# video 1/1 (frame 23/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 15 weeds, 889.2ms
# video 1/1 (frame 24/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 2 roses, 926.0ms
# video 1/1 (frame 25/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 15 weeds, 4 roses, 1193.6ms
# video 1/1 (frame 26/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 15 weeds, 2 roses, 967.6ms
# video 1/1 (frame 27/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 14 weeds, 2 roses, 842.5ms
# video 1/1 (frame 28/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 4 roses, 852.2ms
# video 1/1 (frame 29/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 15 weeds, 2 roses, 699.9ms
# video 1/1 (frame 30/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 2 roses, 913.0ms
# video 1/1 (frame 31/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 785.8ms
# video 1/1 (frame 32/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 860.9ms
# video 1/1 (frame 33/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 15 weeds, 828.4ms
# video 1/1 (frame 34/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 1 rose, 917.4ms
# video 1/1 (frame 35/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 18 weeds, 2 roses, 754.6ms
# video 1/1 (frame 36/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 13 weeds,
765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 867.2ms
# video 1/1 (frame 383/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 18 weeds, 791.9ms
# video 1/1 (frame 384/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 14 weeds, 812.7ms
# video 1/1 (frame 385/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 18 weeds, 709.5ms
# video 1/1 (frame 386/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 805.4ms
# video 1/1 (frame 387/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 765.0ms
# video 1/1 (frame 388/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 15 weeds, 782.8ms
# video 1/1 (frame 389/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 13 weeds, 736.6ms
# video 1/1 (frame 390/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 867.9ms
# video 1/1 (frame 391/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 18 weeds, 768.4ms
# video 1/1 (frame 392/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 802.3ms
# video 1/1 (frame 393/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 18 weeds, 778.7ms
# video 1/1 (frame 394/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 18 weeds, 832.8ms
# video 1/1 (frame 395/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 18 weeds, 739.4ms
# video 1/1 (frame 396/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 753.8ms
# video 1/1 (frame 397/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 18 weeds, 658.4ms
# video 1/1 (frame 398/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 510.8ms
# video 1/1 (frame 399/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 16 weeds, 419.2ms
# video 1/1 (frame 400/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 17 weeds, 405.4ms
# video 1/1 (frame 401/765) D:\Ai Systems Group\data\weeds_yolo\video\rose_row.mp4: 1024x576 19 weeds, 357.3ms
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[7], line 3
#       1 model = YOLO(str(MODEL_PATH))
# ----> 3 results = model.predict(
#       4     source=str(VIDEO_PATH),
#       5     conf=0.30,           # confidence threshold
#       6     imgsz=1024,          # match your training resolution
#       7     device=0,            # GPU (set to 'cpu' if no GPU)
#       8     save=True,           # write the annotated video
#       9     project=str(OUT_DIR),
#      10     name="video_prediction",
#      11     vid_stride=1,        # process every frame (increase to 2+ for speed)
#      12     classes=[0, 1],      # detect roses and weeds (adjust if needed)
#      13 )
#      15 print(" Saved to:", OUT_DIR / "video_prediction")
#
# File D:\Anaconda\envs\yolo\lib\site-packages\ultralytics\engine\model.py:540, in Model.predict(self, source, stream, predictor, **kwargs)
#     538 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     539     self.predictor.set_prompts(prompts)
# --> 540 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File D:\Anaconda\envs\yolo\lib\site-packages\ultralytics\engine\predictor.py:225, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     223     return self.stream_inference(source, model, *args, **kwargs)
#     224 else:
# --> 225     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File D:\Anaconda\envs\yolo\lib\site-packages\torch\utils\_contextlib.py:57, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      54         else:
#      55             # Pass the last request to the generator and get its response
#      56             with ctx_factory():
# ---> 57                 response = gen.send(request)
#      59 # We let the exceptions raised above by the generator's `.throw` or
#      60 # `.send` methods bubble up to our caller, except for StopIteration
#      61 except StopIteration as e:
#      62     # The generator informed us that it is done: take whatever its
#      63     # returned value (if any) was and indicate that we're done too
#      64     # by returning it (see docs for python's return-statement).
#
# File D:\Anaconda\envs\yolo\lib\site-packages\ultralytics\engine\predictor.py:349, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     343         self.results[i].speed = {
#     344             "preprocess": profilers[0].dt * 1e3 / n,
#     345             "inference": profilers[1].dt * 1e3 / n,
#     346             "postprocess": profilers[2].dt * 1e3 / n,
#     347         }
#     348         if self.args.verbose or self.args.save or self.args.save_txt or self.args.show:
# --> 349             s[i] += self.write_results(i, Path(paths[i]), im, s)
#     350 except StopIteration:
#     351     break
#
# File D:\Anaconda\envs\yolo\lib\site-packages\ultralytics\engine\predictor.py:435, in BasePredictor.write_results(self, i, p, im, s)
#     433 # Add predictions to image
#     434 if self.args.save or self.args.show:
# --> 435     self.plotted_img = result.plot(
#     436         line_width=self.args.line_width,
#     437         boxes=self.args.show_boxes,
#     438         conf=self.args.show_conf,
#     439         labels=self.args.show_labels,
#     440         im_gpu=None if self.args.retina_masks else im[i],
#     441     )
#     443 # Save results
#     444 if self.args.save_txt:
#
# File D:\Anaconda\envs\yolo\lib\site-packages\ultralytics\engine\results.py:543, in Results.plot(self, conf, line_width, font_size, font, pil, img, im_gpu, kpt_radius, kpt_line, labels, boxes, masks, probs, show, save, filename, color_mode, txt_color)
#     529         im_gpu = (
#     530             torch.as_tensor(img, dtype=torch.float16, device=pred_masks.data.device)
#     531             .permute(2, 0, 1)
#    (...)
#     534             / 255
#     535         )
#     536     idx = (
#     537         pred_boxes.id
#     538         if pred_boxes.is_track and color_mode == "instance"
#    (...)
#     541         else reversed(range(len(pred_masks)))
#     542     )
# --> 543     annotator.masks(pred_masks.data, colors=[colors(x, True) for x in idx], im_gpu=im_gpu)
#     545 # Plot Detect results
#     546 if pred_boxes is not None and show_boxes:
#
# File D:\Anaconda\envs\yolo\lib\site-packages\ultralytics\utils\plotting.py:402, in Annotator.masks(self, masks, colors, im_gpu, alpha, retina_masks)
#     400 masks = masks.unsqueeze(3)  # shape(n,h,w,1)
#     401 masks_color = masks * (colors * alpha)  # shape(n,h,w,3)
# --> 402 inv_alpha_masks = (1 - masks * alpha).cumprod(0)  # shape(n,h,w,1)
#     403 mcs = masks_color.max(dim=0).values  # shape(n,h,w,3)
#     405 im_gpu = im_gpu.flip(dims=[0]).permute(1, 2, 0).contiguous()  # shape(h,w,3)
#
# File D:\Anaconda\envs\yolo\lib\site-packages\torch\_tensor.py:39, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(*args, **kwargs)
#      37     if has_torch_function(args):
#      38         return handle_torch_function(wrapped, args, *args, **kwargs)
# ---> 39     return f(*args, **kwargs)
#      40 except TypeError:
#      41     return NotImplemented
#
# File D:\Anaconda\envs\yolo\lib\site-packages\torch\_tensor.py:1028, in Tensor.__rsub__(self, other)
#    1026 @_handle_torch_function_and_wrap_type_error_to_not_implemented
#    1027 def __rsub__(self, other):
# -> 1028     return _C._VariableFunctions.rsub(self, other)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 182.00 MiB. GPU 0 has a total capacity of 8.00 GiB of which 0 bytes is free. Of the allocated memory 13.81 GiB is allocated by PyTorch, and 435.55 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ### 3. Convert YOLO output `.avi` to `.mp4`
#
# YOLOv8 saves videos as `.avi` by default for compatibility.
# This cell converts your `.avi` result to a high-quality `.mp4` using H.264 encoding.
# The conversion is **lossless** (no quality degradation).

# %%
import cv2
from pathlib import Path

SOURCE_PATH = Path(r"/model_predictions/video_prediction2/rose_row.avi")
DESTINATION_PATH = SOURCE_PATH.with_suffix(".mp4")

cap = cv2.VideoCapture(str(SOURCE_PATH))
fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
w   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h   = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(str(DESTINATION_PATH), fourcc, float(fps), (w, h))

while True:
    ok, frame = cap.read()
    if not ok:
        break
    out.write(frame)

cap.release()
out.release()
print(f"Conversion complete: {DESTINATION_PATH}")
# Out:
# Conversion complete: D:\Ai Systems Group\model_predictions\video_prediction3\rose_row.mp4
